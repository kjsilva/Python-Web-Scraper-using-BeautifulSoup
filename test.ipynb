# %%
#importing needed libraries
from bs4 import BeautifulSoup
import requests
import json

# %%
#website's url
lamudi_url = 'https://www.lamudi.com.ph/buy/commercial/'

#request from the server
req_info = requests.get(lamudi_url)
req_info_text = req_info.text

#parse the result using BS
soup = BeautifulSoup(req_info_text, 'html.parser')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-PH" prefix="og: http://ogp.me/ns#">
#  <head>
#   <script>
# ...
